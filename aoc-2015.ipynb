# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
nb_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
sys.path.insert(0,nb_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-1-01a0301fcd81> in <module>()
#       3 drive.mount('/content/drive')
#       4 nb_path = '/content/notebooks'
# ----> 5 os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
#       6 sys.path.insert(0,nb_path)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/My Drive/Colab Notebooks' -> '/content/notebooks'

# %%
from aocd.models import Puzzle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8dc9d7bf7cbf> in <module>()
# ----> 1 from aocd.models import Puzzle
#
# ModuleNotFoundError: No module named 'aocd'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from aocd import get_data
get_data(day=1, year=2015)
# Out:
# ERROR: AoC session ID is needed to get your puzzle data!
# You can find it in your browser cookies after login.
#     1) Save the cookie into a text file /root/.config/aocd/token, or
#     2) Export the cookie in environment variable AOC_SESSION
#
# See https://github.com/wimglenn/advent-of-code-wim/issues/1 for more info.
# ---------------------------------------------------------------------------
# AocdError                                 Traceback (most recent call last)
# <ipython-input-13-9327aa7e7f77> in <module>()
#       1 from aocd import get_data
# ----> 2 get_data(day=1, year=2015)
#
# /content/notebooks/aocd/get.py in get_data(session, day, year, block)
#      29     """
#      30     if session is None:
# ---> 31         user = default_user()
#      32     else:
#      33         user = User(token=session)
#
# /content/notebooks/aocd/models.py in default_user()
#     148     )
#     149     cprint(msg.format(os.path.join(AOCD_CONFIG_DIR, "token")), color="red", file=sys.stderr)
# --> 150     raise AocdError("Missing session ID")
#     151
#     152
#
# AocdError: Missing session ID
